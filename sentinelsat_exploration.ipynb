# %%
from sentinelsat import SentinelAPI
import geopandas as gpd
import folium
from shapely.geometry import MultiPolygon, Polygon
from datetime import date

# %%
user = 'matttk'
key = ''
api = SentinelAPI(user, key, 'https://scihub.copernicus.eu/dhus')

# %%
wa = gpd.read_file('f:\\github\\NCRP\\DeepLearning\\data\\gz_2010_us_040_00_500k.json')


m = folium.Map(location=[47.751076, -120.740135], zoom_start=7)

# %%
wa
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA  \
# 0   0400000US23    23                 Maine        30842.923
# 1   0400000US25    25         Massachusetts         7800.058
# 2   0400000US26    26              Michigan        56538.901
# 3   0400000US30    30               Montana       145545.801
# 4   0400000US32    32                Nevada       109781.180
# 5   0400000US34    34            New Jersey         7354.220
# 6   0400000US36    36              New York        47126.399
# 7   0400000US37    37        North Carolina        48617.905
# 8   0400000US39    39                  Ohio        40860.694
# 9   0400000US42    42          Pennsylvania        44742.703
# 10  0400000US44    44          Rhode Island         1033.814
# 11  0400000US47    47             Tennessee        41234.896
# 12  0400000US48    48                 Texas       261231.711
# 13  0400000US49    49                  Utah        82169.620
# ...

# %%
wa_multi = gpd.GeoSeries(wa.iloc[14]['geometry'])

# %%
type(wa_multi)
# Out:
# geopandas.geoseries.GeoSeries

# %%
wa_json = wa_multi.to_json()

# %%
type(wa_json)
# Out:
# str

# %%
folium.GeoJson(wa_json).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
wa_json
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {}, "geometry": {"type": "MultiPolygon", "coordinates": [[[[-123.090546, 49.001976], [-123.035393, 49.002154], [-123.021459, 48.977299], [-123.028091, 48.973943], [-123.040967, 48.977305], [-123.060717, 48.975388], [-123.083834, 48.976139], [-123.084498, 48.986535], [-123.090546, 49.001976]]], [[[-123.025486, 48.717966], [-123.019699, 48.721312], [-123.009787, 48.722291], [-123.007511, 48.718863], [-123.005086, 48.694342], [-123.014449, 48.684978], [-123.021215, 48.681416], [-123.042337, 48.675663], [-123.041645, 48.678633], [-123.035672, 48.68535], [-123.03636, 48.69008], [-123.047058, 48.695772], [-123.070427, 48.699971], [-123.040179, 48.717296], [-123.025486, 48.717966]]], [[[-122.695907, 48.737273], [-122.668947, 48.706644], [-122.663259, 48.697077], [-122.644901, 48.691389], [-122.618225, 48.670721], [-122.609576, 48.645018], [-122.616956, 48.645563], [-122.635299, 48.651846], [-122.673538,
# ...

# %%
wa_multi
# Out:
# 0    MULTIPOLYGON (((-123.09055 49.00198, -123.0353...
# dtype: geometry

# %%
footprint = None
for i in wa_multi:
    footprint = i

# %%
# Query is bugging out. SOmething about request being too long. Research showed that our query is getting too much data and we are exceeding some limit.
    # Suspect that we'll need to chop up WA into smaller chunks and query each chunk then stitch everything back together
# products = api.query(footprint,
#                      date=('20151219', date(2015, 12, 29)),
#                      platformname='Sentinel-2')
